# %% [markdown]
# <a href="https://colab.research.google.com/github/ChoHyeonJun86/machine-learning-prac/blob/main/250604_random_image_segrmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate  # 기존에 사용하지 않은 UpSampling2D, concatenate layer확인 가능
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
from tensorflow.keras import backend as K

# %% [markdown]
# # 랜덤 이미지 생성 및 확인

# %%
def generate_p_data(num_samples=100, img_size=128):

    X = np.random.choice(
        [0.8, 0.4, 0.1],  # 이미지 픽셀 타입
        size=(num_samples, img_size, img_size, 1),
        p=[0.05, 0.25, 0.7]  # 픽셀 비율 설정
    )
    Y = (X > 0.5).astype(np.float32)  # Threshold를 기준으로 마스크 생성
    return X, Y

# %%
sample = generate_p_data(num_samples=100, img_size=128) # 128*128사이즈의 이미지
sample[0].shape
# Out:
# (100, 128, 128, 1)

# %%
sample[1].shape
# Out:
# (100, 128, 128, 1)

# %%
#sample 출력
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(sample[0][i].squeeze(), cmap='gray')
    plt.axis('off')
plt.show()

# %%
X, Y = generate_p_data(num_samples=200, img_size=128) #128*128 사이즈
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # 세그멘테이션 성능 평가 지표

# %%
#세그멘테이션 성능 평가 dice, iou

def dice_coef(y_true, y_pred, smooth=100):  #교집합*2/집합A+집합B
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)

    intersection = K.sum(y_true_flatten * y_pred_flatten)
    union = K.sum(y_true_flatten) + K.sum(y_pred_flatten)
    return (2 * intersection + smooth) / (union + smooth)

def dice_loss(y_true, y_pred, smooth=100):
    return -dice_coef(y_true, y_pred, smooth)

def iou_coef(y_true, y_pred, smooth=100): #교집합/합집합
    intersection = K.sum(y_true * y_pred)
    sum = K.sum(y_true + y_pred)
    iou = (intersection + smooth) / (sum - intersection + smooth)
    return iou

# %% [markdown]
# # 모델 정의

# %%
def unet_model(input_size=(128, 128, 1)):
    inputs = Input(input_size)

    # 다운샘플링
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

    # 업샘플링
    u1 = UpSampling2D((2, 2))(c4) #Skip Connenction
    u1 = concatenate([u1, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(u1)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u2 = UpSampling2D((2, 2))(c5)
    u2 = concatenate([u2, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(u2)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u3 = UpSampling2D((2, 2))(c6)
    u3 = concatenate([u3, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(u3)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7) # 검/흰 이진 분류이므로 sigmoid

    model = Model(inputs, outputs)
    return model

# %%
model = unet_model()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',iou_coef,dice_coef])  # 이진분류이므로 손실함수 binary_crossentropy 사용

# %% [markdown]
# # 모델 학습 및 성능 평가

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 506ms/step - accuracy: 0.7045 - dice_coef: 0.0792 - iou_coef: 0.0423 - loss: 0.5938 - val_accuracy: 0.9498 - val_dice_coef: 0.0296 - val_iou_coef: 0.0189 - val_loss: 0.2951
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.9496 - dice_coef: 0.0534 - iou_coef: 0.0293 - loss: 0.2592 - val_accuracy: 0.9498 - val_dice_coef: 0.0476 - val_iou_coef: 0.0270 - val_loss: 0.2153
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.9496 - dice_coef: 0.0553 - iou_coef: 0.0301 - loss: 0.2181 - val_accuracy: 0.9498 - val_dice_coef: 0.0481 - val_iou_coef: 0.0273 - val_loss: 0.2126
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9497 - dice_coef: 0.0531 - iou_coef: 0.0290 - loss: 0.2116 - val_accuracy: 0.9498 - val_dice_coef: 0.0544 - val_iou_coef: 0.0304 - val_loss: 0.2071
# Epoch 5/10
# ...

# %%
loss, accuracy, iou, dc = model.evaluate(X_test, Y_test)  #Unet 모델이 반환하는 loss, accuracy, iou, dc으로 평가 시작
print(f"test loss: {loss:.4f}, test accuracy: {accuracy:.4f}, dice coef: {dc}, iou coef: {iou}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9901 - dice_coef: 0.6800 - iou_coef: 0.5167 - loss: 0.0371
# test loss: 0.0370, test accuracy: 0.9901, dice coef: 0.6803416609764099, iou coef: 0.5174804329872131

# %%
preds = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 945ms/step

# %%
def plot_results(X, Y_true, Y_pred, num_samples=5):
    plt.figure(figsize=(15, num_samples * 5))
    for i in range(num_samples):
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(X[i].squeeze(), cmap='gray')
        plt.title("Input Image")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(Y_true[i].squeeze(), cmap='gray')
        plt.title("True Mask")
        plt.axis('off')

        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.imshow(Y_pred[i].squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
plot_results(X_test, Y_test, preds)
